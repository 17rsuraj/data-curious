# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
import pandas as pd
import numpy as np
# Out:
# <style>.container { width:100% !important; }</style>

# %%
df = pd.read_csv("Dummy_Sales_Data_v1.csv")
df.head()
# Out:
#                OrderID  Quantity  UnitPrice(USD)         Status   OrderDate  \
# 0  2951110000999929511        92             238  Not Delivered  2021-08-08
# 1  2181910000999921819        61             136  Not Delivered  2021-10-03
# 2  3239110000999932391        67             235  Not Delivered  2021-09-27
# 3  1112610000999911126        33             133    Not Shipped  2021-07-30
# 4  1548310000999915483        13             189  Not Delivered  2021-08-15
#
#   Product_Category Sales_Manager  Shipping_Cost(USD)  Delivery_Time(Days)  \
# 0       Healthcare         Pablo                  21                 25.0
# 1           Office         Pablo                  34                 14.0
# 2           Office       Kristen                  25                 11.0
# 3          Fashion         Abdul                  34                 24.0
# 4          Fashion        Stella                  24                 19.0
#
#   Shipping_Address Product_Code  OrderCode
# ...

# %%
df_group = df.groupby("Product_Category")
type(df_group)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
df_group.mean()
# Out:
#                        OrderID   Quantity  UnitPrice(USD)  Shipping_Cost(USD)  \
# Product_Category
# Entertainment     3.027506e+18  49.851118      176.038618           27.579776
# Fashion           3.005516e+18  51.255200      176.117199           27.685439
# Healthcare        3.065461e+18  50.905274      175.489503           27.519201
# Home              3.018032e+18  50.705340      175.354854           27.537864
# Office            2.998968e+18  50.913476      175.127300           27.522128
#
#                   Delivery_Time(Days)      OrderCode
# Product_Category
# Entertainment               17.492088  444675.193598
# Fashion                     17.443199  444686.966514
# Healthcare                  17.563758  444687.180236
# Home                        17.596388  444680.573301
# Office                      17.497505  444682.908503

# %%
for key, value in df_group:
    print(key)
    print(value)
# Out:
# Entertainment
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 5     4934810000999949348        51             204  Not Delivered
# 12    3882310000999938823        78             219      Delivered
# 20    2469010000999924690        15             156        Shipped
# 21    4030410000999940304        21             123  Not Delivered
# 23    3629310000999936293        78             155      Delivered
# ...                   ...       ...             ...            ...
# 9968  4220510000999942205        39             145        Shipped
# 9973  1074010000999910740         2             186  Not Delivered
# 9990  4241810000999942418        94             211    Not Shipped
# 9993  2363310000999923633        82             116        Shipped
# 9998  1468010000999914680        53             229      Delivered
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 5     2021-11-13    Entertainment         Abdul                  32
# ...

# %%
df_group.get_group('Healthcare')
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 0     2951110000999929511        92             238  Not Delivered
# 6     2750410000999927504        73             242  Not Delivered
# 14    2559910000999925599        55             233  Not Delivered
# 19    4276410000999942764        83             224  Not Delivered
# 22    2111510000999921115        74             250      Delivered
# ...                   ...       ...             ...            ...
# 9981  4904910000999949049        73             209        Shipped
# 9983  4107210000999941072        57             162  Not Delivered
# 9986  1868610000999918686        30             162  Not Delivered
# 9988  4264110000999942641         4             187  Not Delivered
# 9995  1847410000999918474        37             135        Shipped
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 0     2021-08-08       Healthcare         Pablo                  21
# ...

# %%
df[df["Status"]=='Not Delivered']
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 0     2951110000999929511        92             238  Not Delivered
# 1     2181910000999921819        61             136  Not Delivered
# 2     3239110000999932391        67             235  Not Delivered
# 4     1548310000999915483        13             189  Not Delivered
# 5     4934810000999949348        51             204  Not Delivered
# ...                   ...       ...             ...            ...
# 9974  4241810000999942418        79             220  Not Delivered
# 9983  4107210000999941072        57             162  Not Delivered
# 9986  1868610000999918686        30             162  Not Delivered
# 9988  4264110000999942641         4             187  Not Delivered
# 9994  2301610000999923016        75             201  Not Delivered
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 0     2021-08-08       Healthcare         Pablo                  21
# ...

# %%
df.groupby("Status").get_group('Not Delivered')
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 0     2951110000999929511        92             238  Not Delivered
# 1     2181910000999921819        61             136  Not Delivered
# 2     3239110000999932391        67             235  Not Delivered
# 4     1548310000999915483        13             189  Not Delivered
# 5     4934810000999949348        51             204  Not Delivered
# ...                   ...       ...             ...            ...
# 9974  4241810000999942418        79             220  Not Delivered
# 9983  4107210000999941072        57             162  Not Delivered
# 9986  1868610000999918686        30             162  Not Delivered
# 9988  4264110000999942641         4             187  Not Delivered
# 9994  2301610000999923016        75             201  Not Delivered
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 0     2021-08-08       Healthcare         Pablo                  21
# ...

# %%
# %%timeit
df_group.get_group('Home')
# Out:
# 358 µs ± 28.5 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %%timeit
df[df["Product_Category"]=='Home']
# Out:
# 1.2 ms ± 232 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
df.groupby("Product_Category").first()
# Out:
#                               OrderID  Quantity  UnitPrice(USD)  \
# Product_Category
# Entertainment     4934810000999949348        51             204
# Fashion           1112610000999911126        33             133
# Healthcare        2951110000999929511        92             238
# Home              4337210000999943372        57             226
# Office            2181910000999921819        61             136
#
#                          Status   OrderDate Sales_Manager  Shipping_Cost(USD)  \
# Product_Category
# Entertainment     Not Delivered  2021-11-13         Abdul                  32
# Fashion             Not Shipped  2021-07-30         Abdul                  34
# Healthcare        Not Delivered  2021-08-08         Pablo                  21
# Home                Not Shipped  2021-09-27          John                  24
# Office            Not Delivered  2021-10-03         Pablo                  34
#
# ...

# %%
df.groupby("Product_Category").last()
# Out:
#                               OrderID  Quantity  UnitPrice(USD)  \
# Product_Category
# Entertainment     1468010000999914680        53             229
# Fashion           2281610000999922816        18             117
# Healthcare        1847410000999918474        37             135
# Home              2301610000999923016        75             201
# Office            2385710000999923857        81             207
#
#                          Status   OrderDate Sales_Manager  Shipping_Cost(USD)  \
# Product_Category
# Entertainment         Delivered  2021-07-12       Anthony                  25
# Fashion                 Shipped  2021-12-23        Stella                  22
# Healthcare              Shipped  2021-10-03         Maria                  30
# Home              Not Delivered  2021-10-16         Sofia                  20
# Office                Delivered  2021-11-13          Emma                  29
#
# ...

# %%
df.groupby("Product_Category").nth(3)
# Out:
#                               OrderID  Quantity  UnitPrice(USD)  \
# Product_Category
# Entertainment     4030410000999940304        21             123
# Fashion           2804110000999928041        31             163
# Healthcare        4276410000999942764        83             224
# Home              3105110000999931051        79             213
# Office            1444810000999914448         5             119
#
#                          Status   OrderDate Sales_Manager  Shipping_Cost(USD)  \
# Product_Category
# Entertainment     Not Delivered  2021-10-10       Kristen                  30
# Fashion             Not Shipped  2021-12-23         Abdul                  34
# Healthcare        Not Delivered  2021-07-10         Sofia                  24
# Home                  Delivered  2021-10-26         Abdul                  27
# Office              Not Shipped  2021-10-13        Stella                  33
#
# ...

# %%
df.groupby("Product_Category").get_group('Entertainment')
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 5     4934810000999949348        51             204  Not Delivered
# 12    3882310000999938823        78             219      Delivered
# 20    2469010000999924690        15             156        Shipped
# 21    4030410000999940304        21             123  Not Delivered
# 23    3629310000999936293        78             155      Delivered
# ...                   ...       ...             ...            ...
# 9968  4220510000999942205        39             145        Shipped
# 9973  1074010000999910740         2             186  Not Delivered
# 9990  4241810000999942418        94             211    Not Shipped
# 9993  2363310000999923633        82             116        Shipped
# 9998  1468010000999914680        53             229      Delivered
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 5     2021-11-13    Entertainment         Abdul                  32
# ...

# %%
df.groupby("Product_Category").nth(-1)
# Out:
#                               OrderID  Quantity  UnitPrice(USD)  \
# Product_Category
# Entertainment     1468010000999914680        53             229
# Fashion           2281610000999922816        18             117
# Healthcare        1847410000999918474        37             135
# Home              2301610000999923016        75             201
# Office            2385710000999923857        81             207
#
#                          Status   OrderDate Sales_Manager  Shipping_Cost(USD)  \
# Product_Category
# Entertainment         Delivered  2021-07-12       Anthony                  25
# Fashion                 Shipped  2021-12-23        Stella                  22
# Healthcare              Shipped  2021-10-03         Maria                  30
# Home              Not Delivered  2021-10-16         Sofia                  20
# Office                Delivered  2021-11-13          Emma                  29
#
# ...

# %%
df.groupby("Product_Category").get_group('Entertainment').tail()
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 9968  4220510000999942205        39             145        Shipped
# 9973  1074010000999910740         2             186  Not Delivered
# 9990  4241810000999942418        94             211    Not Shipped
# 9993  2363310000999923633        82             116        Shipped
# 9998  1468010000999914680        53             229      Delivered
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 9968  2021-12-29    Entertainment         Sofia                  21
# 9973  2021-07-22    Entertainment          John                  35
# 9990  2021-07-07    Entertainment          Emma                  27
# 9993  2021-09-21    Entertainment          Emma                  33
# 9998  2021-07-12    Entertainment       Anthony                  25
#
#       Delivery_Time(Days) Shipping_Address Product_Code  OrderCode
# 9968                 25.0            Kenya      ENT-901     445559
# ...

# %%
df.groupby("Product_Category").size()
# Out:
# Product_Category
# Entertainment    1968
# Fashion          1971
# Healthcare       1953
# Home             2060
# Office           2011
# dtype: int64

# %%
df.groupby("Product_Category").count()
# Out:
#                   OrderID  Quantity  UnitPrice(USD)  Status  OrderDate  \
# Product_Category
# Entertainment        1968      1968            1968    1968       1968
# Fashion              1971      1971            1971    1971       1971
# Healthcare           1953      1953            1953    1953       1953
# Home                 2060      2060            2060    2060       2060
# Office               2011      2011            2011    2011       2011
#
#                   Sales_Manager  Shipping_Cost(USD)  Delivery_Time(Days)  \
# Product_Category
# Entertainment              1968                1968                 1959
# Fashion                    1971                1971                 1963
# Healthcare                 1953                1953                 1937
# Home                       2060                2060                 2049
# Office                     2011                2011                 2004
#
#                   Shipping_Address  Product_Code  OrderCode
# ...

# %%
df.groupby("Sales_Manager").get_group('Abdul')
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 3     1112610000999911126        33             133    Not Shipped
# 5     4934810000999949348        51             204  Not Delivered
# 7     4797510000999947975        48             240      Delivered
# 8     2804110000999928041        31             163    Not Shipped
# 18    3105110000999931051        79             213      Delivered
# ...                   ...       ...             ...            ...
# 9926  2687610000999926876        30             238  Not Delivered
# 9931  3964010000999939640        16             125        Shipped
# 9941  2030510000999920305        94             212      Delivered
# 9946  3812710000999938127        93             227      Delivered
# 9983  4107210000999941072        57             162  Not Delivered
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 3     2021-07-30          Fashion         Abdul                  34
# ...

# %%
for name_of_group, contents_of_group in df_group:
    print(name_of_group)
    print(contents_of_group)
# Out:
# Entertainment
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 5     4934810000999949348        51             204  Not Delivered
# 12    3882310000999938823        78             219      Delivered
# 20    2469010000999924690        15             156        Shipped
# 21    4030410000999940304        21             123  Not Delivered
# 23    3629310000999936293        78             155      Delivered
# ...                   ...       ...             ...            ...
# 9968  4220510000999942205        39             145        Shipped
# 9973  1074010000999910740         2             186  Not Delivered
# 9990  4241810000999942418        94             211    Not Shipped
# 9993  2363310000999923633        82             116        Shipped
# 9998  1468010000999914680        53             229      Delivered
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 5     2021-11-13    Entertainment         Abdul                  32
# ...

# %%
#Create a groupby object
df_group = df.groupby("Product_Category")

#Select only required columns
df_columns = df_group[["UnitPrice(USD)","Quantity"]]

#Apply aggregate function
df_columns.mean()
# Out:
#                   UnitPrice(USD)   Quantity
# Product_Category
# Entertainment         176.038618  49.851118
# Fashion               176.117199  51.255200
# Healthcare            175.489503  50.905274
# Home                  175.354854  50.705340
# Office                175.127300  50.913476

# %%
df.groupby("Product_Category")[["UnitPrice(USD)","Quantity"]].mean()
# Out:
#                   UnitPrice(USD)   Quantity
# Product_Category
# Entertainment         176.038618  49.851118
# Fashion               176.117199  51.255200
# Healthcare            175.489503  50.905274
# Home                  175.354854  50.705340
# Office                175.127300  50.913476

# %%
df.groupby("Product_Category")[["Quantity"]].aggregate([min,
                                                        max,
                                                        sum,
                                                        'mean'])
# Out:
#                  Quantity
#                       min  max     sum       mean
# Product_Category
# Entertainment           1  100   98107  49.851118
# Fashion                 1  100  101024  51.255200
# Healthcare              1  100   99418  50.905274
# Home                    1  100  104453  50.705340
# Office                  1  100  102387  50.913476

# %%
df.groupby("Product_Category")[["Quantity"]].aggregate([min,
                                                        max,
                                                        sum,
                                                        mean])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-78a6fd5254ab> in <module>
#       2                                                         max,
#       3                                                         sum,
# ----> 4                                                         mean])
#
# NameError: name 'mean' is not defined

# %%
df.groupby("Product_Category").aggregate({'OrderID':'count',
                                          'Quantity':'mean'})
# Out:
#                   OrderID   Quantity
# Product_Category
# Entertainment        1968  49.851118
# Fashion              1971  51.255200
# Healthcare           1953  50.905274
# Home                 2060  50.705340
# Office               2011  50.913476

# %%
function_dictionary = {'OrderID':'count','Quantity':'mean'}
df.groupby("Product_Category").aggregate(function_dictionary)
# Out:
#                   OrderID   Quantity
# Product_Category
# Entertainment        1968  49.851118
# Fashion              1971  51.255200
# Healthcare           1953  50.905274
# Home                 2060  50.705340
# Office               2011  50.913476

# %%
df.groupby("Product_Category").describe()
# Out:
#                  OrderID                                            \
#                    count          mean           std           min
# Product_Category
# Entertainment     1968.0  3.027506e+18  1.173805e+18  1.010410e+18
# Fashion           1971.0  3.005516e+18  1.168951e+18  1.011610e+18
# Healthcare        1953.0  3.065461e+18  1.171580e+18  1.010010e+18
# Home              2060.0  3.018032e+18  1.164170e+18  1.010810e+18
# Office            2011.0  2.998968e+18  1.157488e+18  1.010910e+18
#
#                                                                           \
#                            25%           50%           75%           max
# Product_Category
# Entertainment     1.980360e+18  3.043160e+18  4.020010e+18  5.048510e+18
# Fashion           1.989460e+18  2.933110e+18  4.022660e+18  5.049210e+18
# Healthcare        2.059210e+18  3.013610e+18  4.094010e+18  5.049610e+18
# Home              2.014860e+18  3.039510e+18  4.024910e+18  5.049610e+18
# ...

# %% [markdown]
# #### Thank you!!
