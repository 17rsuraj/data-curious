# %%
import pandas as pd

# %%
df = pd.read_csv("Dummy_Sales_Data_v1.csv")
df.head()
# Out:
#                OrderID  Quantity  UnitPrice(USD)         Status   OrderDate  \
# 0  2951110000999929511        92             238  Not Delivered  2021-08-08
# 1  2181910000999921819        61             136  Not Delivered  2021-10-03
# 2  3239110000999932391        67             235  Not Delivered  2021-09-27
# 3  1112610000999911126        33             133    Not Shipped  2021-07-30
# 4  1548310000999915483        13             189  Not Delivered  2021-08-15
#
#   Product_Category Sales_Manager  Shipping_Cost(USD)  Delivery_Time(Days)  \
# 0       Healthcare         Pablo                  21                 25.0
# 1           Office         Pablo                  34                 14.0
# 2           Office       Kristen                  25                 11.0
# 3          Fashion         Abdul                  34                 24.0
# 4          Fashion        Stella                  24                 19.0
#
#   Shipping_Address Product_Code  OrderCode
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   OrderID              9999 non-null   int64
#  1   Quantity             9999 non-null   int64
#  2   UnitPrice(USD)       9999 non-null   int64
#  3   Status               9999 non-null   object
#  4   OrderDate            9999 non-null   object
#  5   Product_Category     9963 non-null   object
#  6   Sales_Manager        9999 non-null   object
#  7   Shipping_Cost(USD)   9999 non-null   int64
#  8   Delivery_Time(Days)  9948 non-null   float64
#  9   Shipping_Address     9999 non-null   object
#  10  Product_Code         9999 non-null   object
#  11  OrderCode            9999 non-null   int64
# dtypes: float64(1), int64(5), object(6)
# memory usage: 937.5+ KB

# %%
df = pd.read_csv("Dummy_Sales_Data_v1.csv", parse_dates=["OrderDate"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   OrderID              9999 non-null   int64
#  1   Quantity             9999 non-null   int64
#  2   UnitPrice(USD)       9999 non-null   int64
#  3   Status               9999 non-null   object
#  4   OrderDate            9999 non-null   datetime64[ns]
#  5   Product_Category     9963 non-null   object
#  6   Sales_Manager        9999 non-null   object
#  7   Shipping_Cost(USD)   9999 non-null   int64
#  8   Delivery_Time(Days)  9948 non-null   float64
#  9   Shipping_Address     9999 non-null   object
#  10  Product_Code         9999 non-null   object
#  11  OrderCode            9999 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(5), object(5)
# memory usage: 937.5+ KB

# %%
df = pd.read_csv("Dummy_Sales_Data_v1.csv", dtype=object)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   OrderID              9999 non-null   object
#  1   Quantity             9999 non-null   object
#  2   UnitPrice(USD)       9999 non-null   object
#  3   Status               9999 non-null   object
#  4   OrderDate            9999 non-null   object
#  5   Product_Category     9963 non-null   object
#  6   Sales_Manager        9999 non-null   object
#  7   Shipping_Cost(USD)   9999 non-null   object
#  8   Delivery_Time(Days)  9948 non-null   object
#  9   Shipping_Address     9999 non-null   object
#  10  Product_Code         9999 non-null   object
#  11  OrderCode            9999 non-null   object
# dtypes: object(12)
# memory usage: 937.5+ KB

# %%
df = pd.read_csv("Dummy_Sales_Data_v1.csv", dtype={'UnitPrice(USD)':'float64'}, parse_dates=["OrderDate"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   OrderID              9999 non-null   int64
#  1   Quantity             9999 non-null   int64
#  2   UnitPrice(USD)       9999 non-null   float64
#  3   Status               9999 non-null   object
#  4   OrderDate            9999 non-null   datetime64[ns]
#  5   Product_Category     9963 non-null   object
#  6   Sales_Manager        9999 non-null   object
#  7   Shipping_Cost(USD)   9999 non-null   int64
#  8   Delivery_Time(Days)  9948 non-null   float64
#  9   Shipping_Address     9999 non-null   object
#  10  Product_Code         9999 non-null   object
#  11  OrderCode            9999 non-null   int64
# dtypes: datetime64[ns](1), float64(2), int64(4), object(5)
# memory usage: 937.5+ KB

# %%
df = pd.read_csv("Dummy_Sales_Data_v1.csv",
                 dtype={'UnitPrice(USD)':'float64'},
                 parse_dates=["OrderDate"], na_values = 'Not Delivered')
df.head()
# Out:
#                OrderID  Quantity  UnitPrice(USD)       Status  OrderDate  \
# 0  2951110000999929511        92           238.0          NaN 2021-08-08
# 1  2181910000999921819        61           136.0          NaN 2021-10-03
# 2  3239110000999932391        67           235.0          NaN 2021-09-27
# 3  1112610000999911126        33           133.0  Not Shipped 2021-07-30
# 4  1548310000999915483        13           189.0          NaN 2021-08-15
#
#   Product_Category Sales_Manager  Shipping_Cost(USD)  Delivery_Time(Days)  \
# 0       Healthcare         Pablo                  21                 25.0
# 1           Office         Pablo                  34                 14.0
# 2           Office       Kristen                  25                 11.0
# 3          Fashion         Abdul                  34                 24.0
# 4          Fashion        Stella                  24                 19.0
#
#   Shipping_Address Product_Code  OrderCode
# ...

# %%
df = pd.read_csv("Dummy_Sales_Data_v1.csv",
                 dtype={'UnitPrice(USD)':'float64'},
                 parse_dates=["OrderDate"], na_values = {'Status':'Not Delivered','Product_Code':'F-555'})
df.head()
# Out:
#                OrderID  Quantity  UnitPrice(USD)       Status  OrderDate  \
# 0  2951110000999929511        92           238.0          NaN 2021-08-08
# 1  2181910000999921819        61           136.0          NaN 2021-10-03
# 2  3239110000999932391        67           235.0          NaN 2021-09-27
# 3  1112610000999911126        33           133.0  Not Shipped 2021-07-30
# 4  1548310000999915483        13           189.0          NaN 2021-08-15
#
#   Product_Category Sales_Manager  Shipping_Cost(USD)  Delivery_Time(Days)  \
# 0       Healthcare         Pablo                  21                 25.0
# 1           Office         Pablo                  34                 14.0
# 2           Office       Kristen                  25                 11.0
# 3          Fashion         Abdul                  34                 24.0
# 4          Fashion        Stella                  24                 19.0
#
#   Shipping_Address Product_Code  OrderCode
# ...

# %%
df = pd.read_csv("Dummy_Sales_Data_v1.csv",
                 dtype={'UnitPrice(USD)':'float64'},
                 parse_dates=["OrderDate"], na_values = ['Not Delivered','F-555'])
df.head()
# Out:
#                OrderID  Quantity  UnitPrice(USD)       Status  OrderDate  \
# 0  2951110000999929511        92           238.0          NaN 2021-08-08
# 1  2181910000999921819        61           136.0          NaN 2021-10-03
# 2  3239110000999932391        67           235.0          NaN 2021-09-27
# 3  1112610000999911126        33           133.0  Not Shipped 2021-07-30
# 4  1548310000999915483        13           189.0          NaN 2021-08-15
#
#   Product_Category Sales_Manager  Shipping_Cost(USD)  Delivery_Time(Days)  \
# 0       Healthcare         Pablo                  21                 25.0
# 1           Office         Pablo                  34                 14.0
# 2           Office       Kristen                  25                 11.0
# 3          Fashion         Abdul                  34                 24.0
# 4          Fashion        Stella                  24                 19.0
#
#   Shipping_Address Product_Code  OrderCode
# ...

# %%
df = pd.read_csv("Dummy_Sales_Data_v1.csv",
                 usecols = ["OrderID","Status","Shipping_Address"] )
df.head()
# Out:
#                OrderID         Status Shipping_Address
# 0  2951110000999929511  Not Delivered        Singapore
# 1  2181910000999921819  Not Delivered               UK
# 2  3239110000999932391  Not Delivered            Kenya
# 3  1112610000999911126    Not Shipped              USA
# 4  1548310000999915483  Not Delivered            Kenya

# %%
df = pd.read_csv("Dummy_Sales_Data_v1.csv",
                 index_col = "OrderID" )
df.head()
# Out:
#                      Quantity  UnitPrice(USD)         Status   OrderDate  \
# OrderID
# 2951110000999929511        92             238  Not Delivered  2021-08-08
# 2181910000999921819        61             136  Not Delivered  2021-10-03
# 3239110000999932391        67             235  Not Delivered  2021-09-27
# 1112610000999911126        33             133    Not Shipped  2021-07-30
# 1548310000999915483        13             189  Not Delivered  2021-08-15
#
#                     Product_Category Sales_Manager  Shipping_Cost(USD)  \
# OrderID
# 2951110000999929511       Healthcare         Pablo                  21
# 2181910000999921819           Office         Pablo                  34
# 3239110000999932391           Office       Kristen                  25
# 1112610000999911126          Fashion         Abdul                  34
# 1548310000999915483          Fashion        Stella                  24
#
#                      Delivery_Time(Days) Shipping_Address Product_Code  \
# ...

# %%
df = pd.read_csv("Dummy_Sales_Data_v1.csv",
                 index_col = ["OrderID","Product_Category"] )
df.head()
# Out:
#                                       Quantity  UnitPrice(USD)         Status  \
# OrderID             Product_Category
# 2951110000999929511 Healthcare              92             238  Not Delivered
# 2181910000999921819 Office                  61             136  Not Delivered
# 3239110000999932391 Office                  67             235  Not Delivered
# 1112610000999911126 Fashion                 33             133    Not Shipped
# 1548310000999915483 Fashion                 13             189  Not Delivered
#
#                                        OrderDate Sales_Manager  \
# OrderID             Product_Category
# 2951110000999929511 Healthcare        2021-08-08         Pablo
# 2181910000999921819 Office            2021-10-03         Pablo
# 3239110000999932391 Office            2021-09-27       Kristen
# 1112610000999911126 Fashion           2021-07-30         Abdul
# 1548310000999915483 Fashion           2021-08-15        Stella
#
# ...
