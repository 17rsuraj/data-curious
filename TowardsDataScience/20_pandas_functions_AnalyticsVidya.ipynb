# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import pandas as pd

# %%
df = pd.read_csv("Dummy_Sales_Data_v1.csv")
df.head()
# Out:
#                OrderID  Quantity  UnitPrice(USD)         Status   OrderDate  \
# 0  2951110000999929511        92             238  Not Delivered  2021-08-08
# 1  2181910000999921819        61             136  Not Delivered  2021-10-03
# 2  3239110000999932391        67             235  Not Delivered  2021-09-27
# 3  1112610000999911126        33             133    Not Shipped  2021-07-30
# 4  1548310000999915483        13             189  Not Delivered  2021-08-15
#
#   Product_Category Sales_Manager  Shipping_Cost(USD)  Delivery_Time(Days)  \
# 0       Healthcare         Pablo                  21                 25.0
# 1           Office         Pablo                  34                 14.0
# 2           Office       Kristen                  25                 11.0
# 3          Fashion         Abdul                  34                 24.0
# 4          Fashion        Stella                  24                 19.0
#
#   Shipping_Address Product_Code  OrderCode
# ...

# %%
df.head(7)
# Out:
#                OrderID  Quantity  UnitPrice(USD)         Status   OrderDate  \
# 0  2951110000999929511        92             238  Not Delivered  2021-08-08
# 1  2181910000999921819        61             136  Not Delivered  2021-10-03
# 2  3239110000999932391        67             235  Not Delivered  2021-09-27
# 3  1112610000999911126        33             133    Not Shipped  2021-07-30
# 4  1548310000999915483        13             189  Not Delivered  2021-08-15
# 5  4934810000999949348        51             204  Not Delivered  2021-11-13
# 6  2750410000999927504        73             242  Not Delivered  2021-07-08
#
#   Product_Category Sales_Manager  Shipping_Cost(USD)  Delivery_Time(Days)  \
# 0       Healthcare         Pablo                  21                 25.0
# 1           Office         Pablo                  34                 14.0
# 2           Office       Kristen                  25                 11.0
# ...

# %%
df.tail(3)
# Out:
#                   OrderID  Quantity  UnitPrice(USD)     Status   OrderDate  \
# 9996  2385710000999923857        81             207  Delivered  2021-11-13
# 9997  2281610000999922816        18             117    Shipped  2021-12-23
# 9998  1468010000999914680        53             229  Delivered  2021-07-12
#
#      Product_Category Sales_Manager  Shipping_Cost(USD)  Delivery_Time(Days)  \
# 9996           Office          Emma                  29                 18.0
# 9997          Fashion        Stella                  22                 24.0
# 9998    Entertainment       Anthony                  25                 12.0
#
#      Shipping_Address Product_Code  OrderCode
# 9996              USA        O-203     445113
# 9997            Italy        F-101     445553
# 9998        Singapore      ENT-630     443889

# %%
df.sample()
# Out:
#                   OrderID  Quantity  UnitPrice(USD)       Status   OrderDate  \
# 4536  2885410000999928854        13             177  Not Shipped  2021-07-03
#
#      Product_Category Sales_Manager  Shipping_Cost(USD)  Delivery_Time(Days)  \
# 4536       Healthcare         Jacob                  22                 11.0
#
#      Shipping_Address Product_Code  OrderCode
# 4536        Singapore       HC-901     443880

# %%
df.sample(axis=1)
# Out:
#      Sales_Manager
# 0            Pablo
# 1            Pablo
# 2          Kristen
# 3            Abdul
# 4           Stella
# ...            ...
# 9994         Sofia
# 9995         Maria
# 9996          Emma
# 9997        Stella
# 9998       Anthony
#
# [9999 rows x 1 columns]

# %%
df.sample(axis=0)
# Out:
#                  OrderID  Quantity  UnitPrice(USD)         Status   OrderDate  \
# 320  2067510000999920675        62             114  Not Delivered  2021-09-24
#
#     Product_Category Sales_Manager  Shipping_Cost(USD)  Delivery_Time(Days)  \
# 320             Home          Emma                  20                 23.0
#
#     Shipping_Address Product_Code  OrderCode
# 320            Kenya        H-188     444663

# %%
df.sample(4)
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 4631  1315410000999913154        34             157  Not Delivered
# 1259  2789510000999927895        88             115        Shipped
# 1054  2387410000999923874        68             243  Not Delivered
# 6477  4769910000999947699         7             168      Delivered
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 4631  2021-09-13             Home       Anthony                  23
# 1259  2021-10-10       Healthcare         Maria                  24
# 1054  2021-10-06             Home          Emma                  25
# 6477  2021-10-02           Office         Jacob                  26
#
#       Delivery_Time(Days) Shipping_Address Product_Code  OrderCode
# 4631                 14.0            Italy        H-101     444552
# 1259                 23.0            China       HC-203     444779
# 1054                 14.0              USA        H-101     444775
# ...

# %%
df.sample(4, random_state=1)
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 2065  3851210000999938512        43             201      Delivered
# 5361  3354210000999933542        52             168  Not Delivered
# 961   3396010000999933960        12             231  Not Delivered
# 1756  2474910000999924749        34             118  Not Delivered
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 2065  2021-07-30             Home         Maria                  30
# 5361  2021-10-04       Healthcare        Stella                  33
# 961   2021-11-24          Fashion         Jacob                  33
# 1756  2021-10-04          Fashion         Jacob                  21
#
#       Delivery_Time(Days) Shipping_Address Product_Code  OrderCode
# 2065                 24.0               UK        H-188     444007
# 5361                 20.0            Italy       HC-101     444773
# 961                  12.0            China        F-901     445224
# ...

# %%
df.sample(4, random_state=1)
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 2065  3851210000999938512        43             201      Delivered
# 5361  3354210000999933542        52             168  Not Delivered
# 961   3396010000999933960        12             231  Not Delivered
# 1756  2474910000999924749        34             118  Not Delivered
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 2065  2021-07-30             Home         Maria                  30
# 5361  2021-10-04       Healthcare        Stella                  33
# 961   2021-11-24          Fashion         Jacob                  33
# 1756  2021-10-04          Fashion         Jacob                  21
#
#       Delivery_Time(Days) Shipping_Address Product_Code  OrderCode
# 2065                 24.0               UK        H-188     444007
# 5361                 20.0            Italy       HC-101     444773
# 961                  12.0            China        F-901     445224
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   OrderID              9999 non-null   int64
#  1   Quantity             9999 non-null   int64
#  2   UnitPrice(USD)       9999 non-null   int64
#  3   Status               9999 non-null   object
#  4   OrderDate            9999 non-null   object
#  5   Product_Category     9963 non-null   object
#  6   Sales_Manager        9999 non-null   object
#  7   Shipping_Cost(USD)   9999 non-null   int64
#  8   Delivery_Time(Days)  9948 non-null   float64
#  9   Shipping_Address     9999 non-null   object
#  10  Product_Code         9999 non-null   object
#  11  OrderCode            9999 non-null   int64
# dtypes: float64(1), int64(5), object(6)
# memory usage: 937.5+ KB

# %%
df.dtypes
# Out:
# OrderID                  int64
# Quantity                 int64
# UnitPrice(USD)           int64
# Status                  object
# OrderDate               object
# Product_Category        object
# Sales_Manager           object
# Shipping_Cost(USD)       int64
# Delivery_Time(Days)    float64
# Shipping_Address        object
# Product_Code            object
# OrderCode                int64
# dtype: object

# %%
df.columns
# Out:
# Index(['OrderID', 'Quantity', 'UnitPrice(USD)', 'Status', 'OrderDate',
#        'Product_Category', 'Sales_Manager', 'Shipping_Cost(USD)',
#        'Delivery_Time(Days)', 'Shipping_Address', 'Product_Code', 'OrderCode'],
#       dtype='object')

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
len(df)
# Out:
# 9999

# %%
df.shape
# Out:
# (9999, 12)

# %%
df.size
# Out:
# 119988

# %%
df.describe()
# Out:
#             OrderID     Quantity  UnitPrice(USD)  Shipping_Cost(USD)  \
# count  9.999000e+03  9999.000000     9999.000000         9999.000000
# mean   3.020951e+18    50.739874      175.620662           27.571857
# std    1.167549e+18    29.005532       43.527995            4.610452
# min    1.010010e+18     1.000000      100.000000           20.000000
# 25%    2.010410e+18    26.000000      138.000000           24.000000
# 50%    3.002410e+18    51.000000      176.000000           28.000000
# 75%    4.024510e+18    76.000000      213.000000           32.000000
# max    5.049610e+18   100.000000      250.000000           35.000000
#
#        Delivery_Time(Days)      OrderCode
# count          9948.000000    9999.000000
# mean             17.518396  444682.917392
# std               4.609531     525.343171
# min              10.000000  443880.000000
# 25%              14.000000  444222.000000
# 50%              18.000000  444772.000000
# 75%              22.000000  445113.000000
# ...

# %%
df.describe(include = 'all')
# Out:
#              OrderID     Quantity  UnitPrice(USD)         Status   OrderDate  \
# count   9.999000e+03  9999.000000     9999.000000           9999        9999
# unique           NaN          NaN             NaN              4         108
# top              NaN          NaN             NaN  Not Delivered  2021-10-04
# freq             NaN          NaN             NaN           2572         309
# mean    3.020951e+18    50.739874      175.620662            NaN         NaN
# std     1.167549e+18    29.005532       43.527995            NaN         NaN
# min     1.010010e+18     1.000000      100.000000            NaN         NaN
# 25%     2.010410e+18    26.000000      138.000000            NaN         NaN
# 50%     3.002410e+18    51.000000      176.000000            NaN         NaN
# 75%     4.024510e+18    76.000000      213.000000            NaN         NaN
# max     5.049610e+18   100.000000      250.000000            NaN         NaN
#
# ...

# %%
df.value_counts("Status")
# Out:
# Status
# Not Delivered    2572
# Shipped          2554
# Delivered        2451
# Not Shipped      2422
# dtype: int64

# %%
df.query("Quantity > 95")
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 16    2808810000999928088        96             115      Delivered
# 25    3063710000999930637       100             173  Not Delivered
# 33    3255510000999932555        96             202      Delivered
# 36    4273710000999942737        97             202        Shipped
# 53    1367410000999913674        96             169        Shipped
# ...                   ...       ...             ...            ...
# 9848  3681610000999936816        96             230    Not Shipped
# 9867  3981210000999939812        99             204        Shipped
# 9872  4084910000999940849        98             107    Not Shipped
# 9923  3821010000999938210        98             135  Not Delivered
# 9967  3167110000999931671        99             233      Delivered
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 16    2021-10-17             Home         Jacob                  30
# ...

# %%
df.query("Quantity > 90 and Quantity < 100")
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 0     2951110000999929511        92             238  Not Delivered
# 16    2808810000999928088        96             115      Delivered
# 33    3255510000999932555        96             202      Delivered
# 36    4273710000999942737        97             202        Shipped
# 39    3092710000999930927        91             129    Not Shipped
# ...                   ...       ...             ...            ...
# 9942  4010710000999940107        93             209        Shipped
# 9946  3812710000999938127        93             227      Delivered
# 9967  3167110000999931671        99             233      Delivered
# 9985  1541410000999915414        92             230        Shipped
# 9990  4241810000999942418        94             211    Not Shipped
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 0     2021-08-08       Healthcare         Pablo                  21
# ...

# %%
df.query("Quantity > 90 and Quantity < 100 and Status == 'Delivered'")
# Out:
#                   OrderID  Quantity  UnitPrice(USD)     Status   OrderDate  \
# 16    2808810000999928088        96             115  Delivered  2021-10-17
# 33    3255510000999932555        96             202  Delivered  2021-08-20
# 44    1559510000999915595        94             123  Delivered  2021-11-15
# 120   2648410000999926484        91             118  Delivered  2021-12-18
# 128   1845110000999918451        91             183  Delivered  2021-10-10
# ...                   ...       ...             ...        ...         ...
# 9809  2359910000999923599        98             236  Delivered  2021-10-13
# 9911  2952510000999929525        92             137  Delivered  2021-10-24
# 9941  2030510000999920305        94             212  Delivered  2021-07-11
# 9946  3812710000999938127        93             227  Delivered  2021-12-14
# 9967  3167110000999931671        99             233  Delivered  2021-11-02
#
# ...

# %%
df.loc[100,'Sales_Manager']
# Out:
# 'John'

# %%
df.loc[[100, 200],['Sales_Manager','Status']]
# Out:
#     Sales_Manager         Status
# 100          John  Not Delivered
# 200         Pablo        Shipped

# %%
df.iloc[100,6]
# Out:
# 'John'

# %%
df.iloc[[100, 200],[6,3]]
# Out:
#     Sales_Manager         Status
# 100          John  Not Delivered
# 200         Pablo        Shipped

# %%
df["Sales_Manager"].unique()
# Out:
# array(['Pablo', 'Kristen', 'Abdul', 'Stella', 'Emma', 'John', 'Jacob',
#        'Sofia', 'Maria', 'Anthony'], dtype=object)

# %%
df["Sales_Manager"].nunique()
# Out:
# 10

# %%
df.nunique()
# Out:
# OrderID                8842
# Quantity                100
# UnitPrice(USD)          151
# Status                    4
# OrderDate               108
# Product_Category          5
# Sales_Manager            10
# Shipping_Cost(USD)       16
# Delivery_Time(Days)      16
# Shipping_Address          8
# Product_Code             30
# OrderCode               108
# dtype: int64

# %%
df.isnull()
# Out:
#       OrderID  Quantity  UnitPrice(USD)  Status  OrderDate  Product_Category  \
# 0       False     False           False   False      False             False
# 1       False     False           False   False      False             False
# 2       False     False           False   False      False             False
# 3       False     False           False   False      False             False
# 4       False     False           False   False      False             False
# ...       ...       ...             ...     ...        ...               ...
# 9994    False     False           False   False      False             False
# 9995    False     False           False   False      False             False
# 9996    False     False           False   False      False             False
# 9997    False     False           False   False      False             False
# 9998    False     False           False   False      False             False
#
# ...

# %%
df["Product_Category"].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9994    False
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# Name: Product_Category, Length: 9999, dtype: bool

# %%
df2 = df[df["Product_Category"].isnull()]
df2
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 142   4765310000999947653        59             186  Not Delivered
# 271   1223710000999912237        14             229    Not Shipped
# 829   2392410000999923924         9             226    Not Shipped
# 907   1669610000999916696        51             161    Not Shipped
# 983   1306710000999913067        53             168      Delivered
# 1081  1934010000999919340        44             224        Shipped
# 1231  2436710000999924367        76             124      Delivered
# 1688  1720010000999917200        84             106    Not Shipped
# 1740  1669010000999916690         8             169    Not Shipped
# 1875  4739410000999947394        80             116  Not Delivered
# 2541  1493110000999914931        38             197  Not Delivered
# 3257  2493410000999924934         7             144      Delivered
# 3774  2311410000999923114        72             131    Not Shipped
# ...

# %%
df2.fillna("MissingInfo")
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 142   4765310000999947653        59             186  Not Delivered
# 271   1223710000999912237        14             229    Not Shipped
# 829   2392410000999923924         9             226    Not Shipped
# 907   1669610000999916696        51             161    Not Shipped
# 983   1306710000999913067        53             168      Delivered
# 1081  1934010000999919340        44             224        Shipped
# 1231  2436710000999924367        76             124      Delivered
# 1688  1720010000999917200        84             106    Not Shipped
# 1740  1669010000999916690         8             169    Not Shipped
# 1875  4739410000999947394        80             116  Not Delivered
# 2541  1493110000999914931        38             197  Not Delivered
# 3257  2493410000999924934         7             144      Delivered
# 3774  2311410000999923114        72             131    Not Shipped
# ...

# %%
df2
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 142   4765310000999947653        59             186  Not Delivered
# 271   1223710000999912237        14             229    Not Shipped
# 829   2392410000999923924         9             226    Not Shipped
# 907   1669610000999916696        51             161    Not Shipped
# 983   1306710000999913067        53             168      Delivered
# 1081  1934010000999919340        44             224        Shipped
# 1231  2436710000999924367        76             124      Delivered
# 1688  1720010000999917200        84             106    Not Shipped
# 1740  1669010000999916690         8             169    Not Shipped
# 1875  4739410000999947394        80             116  Not Delivered
# 2541  1493110000999914931        38             197  Not Delivered
# 3257  2493410000999924934         7             144      Delivered
# 3774  2311410000999923114        72             131    Not Shipped
# ...

# %%
df.sort_values("Quantity")
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 3367  4733210000999947332         1             213    Not Shipped
# 5952  2228310000999922283         1             203  Not Delivered
# 5569  3732610000999937326         1             165        Shipped
# 9516  2719510000999927195         1             247  Not Delivered
# 3429  3276610000999932766         1             157    Not Shipped
# ...                   ...       ...             ...            ...
# 7820  2478510000999924785       100             187      Delivered
# 2739  1262510000999912625       100             101        Shipped
# 551   3442310000999934423       100             218  Not Delivered
# 2719  2829410000999928294       100             117    Not Shipped
# 503   2085610000999920856       100             108  Not Delivered
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 3367  2021-07-04    Entertainment         Maria                  26
# ...

# %%
df.sort_values("Quantity", ascending=False)
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 9450  2502610000999925026       100             236    Not Shipped
# 7066  4643510000999946435       100             132        Shipped
# 5848  4016510000999940165       100             189        Shipped
# 4336  3452310000999934523       100             154        Shipped
# 3245  4907310000999949073       100             171  Not Delivered
# ...                   ...       ...             ...            ...
# 7742  1232310000999912323         1             237        Shipped
# 8818  1106110000999911061         1             167      Delivered
# 2314  3552710000999935527         1             117      Delivered
# 2643  4662110000999946621         1             180        Shipped
# 1739  2120410000999921204         1             163    Not Shipped
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 9450  2021-09-07       Healthcare         Abdul                  24
# ...

# %%
df.iloc[142,:]
# Out:
# OrderID                4765310000999947653
# Quantity                                59
# UnitPrice(USD)                         186
# Status                       Not Delivered
# OrderDate                       2021-12-30
# Product_Category                       NaN
# Sales_Manager                      Kristen
# Shipping_Cost(USD)                      28
# Delivery_Time(Days)                   15.0
# Shipping_Address                       USA
# Product_Code                        HC-101
# OrderCode                           445660
# Name: 142, dtype: object

# %%
df.head()
# Out:
#                OrderID  Quantity  UnitPrice(USD)         Status   OrderDate  \
# 0  2951110000999929511        92             238  Not Delivered  2021-08-08
# 1  2181910000999921819        61             136  Not Delivered  2021-10-03
# 2  3239110000999932391        67             235  Not Delivered  2021-09-27
# 3  1112610000999911126        33             133    Not Shipped  2021-07-30
# 4  1548310000999915483        13             189  Not Delivered  2021-08-15
#
#   Product_Category Sales_Manager  Shipping_Cost(USD)  Delivery_Time(Days)  \
# 0       Healthcare         Pablo                  21                 25.0
# 1           Office         Pablo                  34                 14.0
# 2           Office       Kristen                  25                 11.0
# 3          Fashion         Abdul                  34                 24.0
# 4          Fashion        Stella                  24                 19.0
#
#   Shipping_Address Product_Code  OrderCode
# ...

# %%
df.sort_values("Product_Category").head()
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 9998  1468010000999914680        53             229      Delivered
# 1935  2647710000999926477        26             149    Not Shipped
# 5941  2019110000999920191         2             207    Not Shipped
# 5936  2185310000999921853        48             218  Not Delivered
# 5930  2793410000999927934        28             102      Delivered
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 9998  2021-07-12    Entertainment       Anthony                  25
# 1935  2021-09-24    Entertainment          John                  26
# 5941  2021-08-26    Entertainment         Maria                  35
# 5936  2021-07-30    Entertainment         Abdul                  20
# 5930  2021-12-10    Entertainment         Jacob                  31
#
#       Delivery_Time(Days) Shipping_Address Product_Code  OrderCode
# 9998                 12.0        Singapore      ENT-630     443889
# ...

# %%
df.sort_values("Quantity").head()
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 3367  4733210000999947332         1             213    Not Shipped
# 5952  2228310000999922283         1             203  Not Delivered
# 5569  3732610000999937326         1             165        Shipped
# 9516  2719510000999927195         1             247  Not Delivered
# 3429  3276610000999932766         1             157    Not Shipped
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 3367  2021-07-04    Entertainment         Maria                  26
# 5952  2021-12-26    Entertainment         Sofia                  20
# 5569  2021-07-14       Healthcare          Emma                  35
# 9516  2021-07-10           Office        Stella                  35
# 3429  2021-10-03             Home         Abdul                  32
#
#       Delivery_Time(Days) Shipping_Address Product_Code  OrderCode
# 3367                  NaN            China      ENT-630     443881
# ...

# %%
df.sort_values("Quantity", ascending=False).head()
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 9450  2502610000999925026       100             236    Not Shipped
# 7066  4643510000999946435       100             132        Shipped
# 5848  4016510000999940165       100             189        Shipped
# 4336  3452310000999934523       100             154        Shipped
# 3245  4907310000999949073       100             171  Not Delivered
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 9450  2021-09-07       Healthcare         Abdul                  24
# 7066  2021-08-03           Office       Anthony                  35
# 5848  2021-07-14    Entertainment          Emma                  25
# 4336  2021-07-17    Entertainment          John                  28
# 3245  2021-10-06    Entertainment       Kristen                  31
#
#       Delivery_Time(Days) Shipping_Address Product_Code  OrderCode
# 9450                 24.0            Italy       HC-901     444446
# ...

# %%
df.value_counts(["Product_Category","Status"])
# Out:
# Product_Category  Status
# Healthcare        Delivered        556
# Office            Shipped          537
# Home              Shipped          529
# Office            Not Delivered    528
# Entertainment     Not Delivered    523
# Home              Not Delivered    520
#                   Not Shipped      519
# Entertainment     Shipped          512
# Fashion           Not Delivered    511
#                   Not Shipped      496
# Home              Delivered        492
# Entertainment     Not Shipped      487
# Fashion           Shipped          486
# Healthcare        Shipped          483
# Fashion           Delivered        478
# Healthcare        Not Delivered    478
# Office            Not Shipped      476
#                   Delivered        470
# Entertainment     Delivered        446
# Healthcare        Not Shipped      436
# dtype: int64

# %%
df.value_counts("Sales_Manager")
# Out:
# Sales_Manager
# John       1081
# Sofia      1019
# Anthony    1015
# Pablo      1010
# Emma       1007
# Kristen     991
# Stella      987
# Abdul       981
# Jacob       967
# Maria       941
# dtype: int64

# %%
df.nlargest(10, "Delivery_Time(Days)")
# Out:
#                  OrderID  Quantity  UnitPrice(USD)         Status   OrderDate  \
# 0    2951110000999929511        92             238  Not Delivered  2021-08-08
# 16   2808810000999928088        96             115      Delivered  2021-10-17
# 39   3092710000999930927        91             129    Not Shipped  2021-11-21
# 73   2895910000999928959        83             112        Shipped  2021-08-20
# 78   3457310000999934573        95             182    Not Shipped  2021-11-16
# 87   3933610000999939336        57             187        Shipped  2021-12-18
# 98   3059610000999930596        35             167    Not Shipped  2021-11-25
# 122  2491210000999924912        39             246      Delivered  2021-07-10
# 129  1434010000999914340        70             201      Delivered  2021-09-13
# 145  5011710000999950117        23             218  Not Delivered  2021-08-11
#
#     Product_Category Sales_Manager  Shipping_Cost(USD)  Delivery_Time(Days)  \
# ...

# %%
df.nsmallest(7, "Shipping_Cost(USD)")
# Out:
#                  OrderID  Quantity  UnitPrice(USD)         Status   OrderDate  \
# 11   2596010000999925960        44             246      Delivered  2021-07-11
# 30   1408910000999914089         7             130      Delivered  2021-07-04
# 47   2097210000999920972        62             216      Delivered  2021-10-09
# 84   3736410000999937364        87             136    Not Shipped  2021-09-14
# 94   1314010000999913140        85             208  Not Delivered  2021-07-11
# 100  4040610000999940406        93             197  Not Delivered  2021-09-07
# 117  3888310000999938883        18             123        Shipped  2021-11-13
#
#     Product_Category Sales_Manager  Shipping_Cost(USD)  Delivery_Time(Days)  \
# 11            Office        Stella                  20                 12.0
# 30        Healthcare         Sofia                  20                  NaN
# 47              Home          Emma                  20                 10.0
# ...

# %%
df1 = df.iloc[0:10, :].copy()
df1
# Out:
#                OrderID  Quantity  UnitPrice(USD)         Status   OrderDate  \
# 0  2951110000999929511        92             238  Not Delivered  2021-08-08
# 1  2181910000999921819        61             136  Not Delivered  2021-10-03
# 2  3239110000999932391        67             235  Not Delivered  2021-09-27
# 3  1112610000999911126        33             133    Not Shipped  2021-07-30
# 4  1548310000999915483        13             189  Not Delivered  2021-08-15
# 5  4934810000999949348        51             204  Not Delivered  2021-11-13
# 6  2750410000999927504        73             242  Not Delivered  2021-07-08
# 7  4797510000999947975        48             240      Delivered  2021-10-04
# 8  2804110000999928041        31             163    Not Shipped  2021-12-23
# 9  1735910000999917359        62             214  Not Delivered  2021-08-14
#
#   Product_Category Sales_Manager  Shipping_Cost(USD)  Delivery_Time(Days)  \
# ...

# %%
df1.rename(columns = {"Shipping_Cost(USD)": "Shipping_Cost",
                      "Delivery_Time(Days)":"DeliveryTime_in_Days"},
           inplace=True)
df1
# Out:
#                OrderID  Quantity  UnitPrice(USD)         Status   OrderDate  \
# 0  2951110000999929511        92             238  Not Delivered  2021-08-08
# 1  2181910000999921819        61             136  Not Delivered  2021-10-03
# 2  3239110000999932391        67             235  Not Delivered  2021-09-27
# 3  1112610000999911126        33             133    Not Shipped  2021-07-30
# 4  1548310000999915483        13             189  Not Delivered  2021-08-15
# 5  4934810000999949348        51             204  Not Delivered  2021-11-13
# 6  2750410000999927504        73             242  Not Delivered  2021-07-08
# 7  4797510000999947975        48             240      Delivered  2021-10-04
# 8  2804110000999928041        31             163    Not Shipped  2021-12-23
# 9  1735910000999917359        62             214  Not Delivered  2021-08-14
#
#   Product_Category Sales_Manager  Shipping_Cost  DeliveryTime_in_Days  \
# ...

# %%
condition = df1["Status"] == "Not Shipped"
df1.where(condition)
# Out:
#         OrderID  Quantity  UnitPrice(USD)       Status   OrderDate  \
# 0           NaN       NaN             NaN          NaN         NaN
# 1           NaN       NaN             NaN          NaN         NaN
# 2           NaN       NaN             NaN          NaN         NaN
# 3  1.112610e+18      33.0           133.0  Not Shipped  2021-07-30
# 4           NaN       NaN             NaN          NaN         NaN
# 5           NaN       NaN             NaN          NaN         NaN
# 6           NaN       NaN             NaN          NaN         NaN
# 7           NaN       NaN             NaN          NaN         NaN
# 8  2.804110e+18      31.0           163.0  Not Shipped  2021-12-23
# 9           NaN       NaN             NaN          NaN         NaN
#
#   Product_Category Sales_Manager  Shipping_Cost  DeliveryTime_in_Days  \
# 0              NaN           NaN            NaN                   NaN
# 1              NaN           NaN            NaN                   NaN
# ...

# %%
condition = df1["Status"] == "Not Shipped"
df1.where(condition, 'Condition_False')
# Out:
#                OrderID         Quantity   UnitPrice(USD)           Status  \
# 0      Condition_False  Condition_False  Condition_False  Condition_False
# 1      Condition_False  Condition_False  Condition_False  Condition_False
# 2      Condition_False  Condition_False  Condition_False  Condition_False
# 3  1112610000999911126               33              133      Not Shipped
# 4      Condition_False  Condition_False  Condition_False  Condition_False
# 5      Condition_False  Condition_False  Condition_False  Condition_False
# 6      Condition_False  Condition_False  Condition_False  Condition_False
# 7      Condition_False  Condition_False  Condition_False  Condition_False
# 8  2804110000999928041               31              163      Not Shipped
# 9      Condition_False  Condition_False  Condition_False  Condition_False
#
#          OrderDate Product_Category    Sales_Manager    Shipping_Cost  \
# 0  Condition_False  Condition_False  Condition_False  Condition_False
# ...

# %%
df1[["Quantity","Shipping_Cost"]].corr()
# Out:
#                Quantity  Shipping_Cost
# Quantity       1.000000      -0.224508
# Shipping_Cost -0.224508       1.000000

# %%
df1[["Quantity","Shipping_Cost"]].corr(method='pearson')
# Out:
#                Quantity  Shipping_Cost
# Quantity       1.000000      -0.224508
# Shipping_Cost -0.224508       1.000000

# %%
df1.corr()
# Out:
#                        OrderID  Quantity  UnitPrice(USD)  Shipping_Cost  \
# OrderID               1.000000  0.249132        0.528621      -0.127541
# Quantity              0.249132  1.000000        0.545237      -0.224508
# UnitPrice(USD)        0.528621  0.545237        1.000000      -0.622391
# Shipping_Cost        -0.127541 -0.224508       -0.622391       1.000000
# DeliveryTime_in_Days -0.059745 -0.150487       -0.153453      -0.345884
# OrderCode             0.521803 -0.271838       -0.220744       0.250228
#
#                       DeliveryTime_in_Days  OrderCode
# OrderID                          -0.059745   0.521803
# Quantity                         -0.150487  -0.271838
# UnitPrice(USD)                   -0.153453  -0.220744
# Shipping_Cost                    -0.345884   0.250228
# DeliveryTime_in_Days              1.000000  -0.169728
# OrderCode                        -0.169728   1.000000

# %%
df1.drop("OrderCode", axis=1)
# Out:
#                OrderID  Quantity  UnitPrice(USD)         Status   OrderDate  \
# 0  2951110000999929511        92             238  Not Delivered  2021-08-08
# 1  2181910000999921819        61             136  Not Delivered  2021-10-03
# 2  3239110000999932391        67             235  Not Delivered  2021-09-27
# 3  1112610000999911126        33             133    Not Shipped  2021-07-30
# 4  1548310000999915483        13             189  Not Delivered  2021-08-15
# 5  4934810000999949348        51             204  Not Delivered  2021-11-13
# 6  2750410000999927504        73             242  Not Delivered  2021-07-08
# 7  4797510000999947975        48             240      Delivered  2021-10-04
# 8  2804110000999928041        31             163    Not Shipped  2021-12-23
# 9  1735910000999917359        62             214  Not Delivered  2021-08-14
#
#   Product_Category Sales_Manager  Shipping_Cost  DeliveryTime_in_Days  \
# ...

# %%
df1
# Out:
#                OrderID  Quantity  UnitPrice(USD)         Status   OrderDate  \
# 0  2951110000999929511        92             238  Not Delivered  2021-08-08
# 1  2181910000999921819        61             136  Not Delivered  2021-10-03
# 2  3239110000999932391        67             235  Not Delivered  2021-09-27
# 3  1112610000999911126        33             133    Not Shipped  2021-07-30
# 4  1548310000999915483        13             189  Not Delivered  2021-08-15
# 5  4934810000999949348        51             204  Not Delivered  2021-11-13
# 6  2750410000999927504        73             242  Not Delivered  2021-07-08
# 7  4797510000999947975        48             240      Delivered  2021-10-04
# 8  2804110000999928041        31             163    Not Shipped  2021-12-23
# 9  1735910000999917359        62             214  Not Delivered  2021-08-14
#
#   Product_Category Sales_Manager  Shipping_Cost  DeliveryTime_in_Days  \
# ...
