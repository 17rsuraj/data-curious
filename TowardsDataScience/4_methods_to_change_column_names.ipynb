# %%
import pandas as pd
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
df = pd.read_csv("Dummy_Sales_Data_v1.csv")
df.head()
# Out:
#                OrderID  Quantity  UnitPrice(USD)         Status   OrderDate  \
# 0  2951110000999929511        92             238  Not Delivered  2021-08-08
# 1  2181910000999921819        61             136  Not Delivered  2021-10-03
# 2  3239110000999932391        67             235  Not Delivered  2021-09-27
# 3  1112610000999911126        33             133    Not Shipped  2021-07-30
# 4  1548310000999915483        13             189  Not Delivered  2021-08-15
#
#   Product_Category Sales_Manager  Shipping_Cost(USD)  Delivery_Time(Days)  \
# 0       Healthcare         Pablo                  21                 25.0
# 1           Office         Pablo                  34                 14.0
# 2           Office       Kristen                  25                 11.0
# 3          Fashion         Abdul                  34                 24.0
# 4          Fashion        Stella                  24                 19.0
#
#   Shipping_Address Product_Code  OrderCode
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   OrderID              9999 non-null   int64
#  1   Quantity             9999 non-null   int64
#  2   UnitPrice(USD)       9999 non-null   int64
#  3   Status               9999 non-null   object
#  4   OrderDate            9999 non-null   object
#  5   Product_Category     9963 non-null   object
#  6   Sales_Manager        9999 non-null   object
#  7   Shipping_Cost(USD)   9999 non-null   int64
#  8   Delivery_Time(Days)  9948 non-null   float64
#  9   Shipping_Address     9999 non-null   object
#  10  Product_Code         9999 non-null   object
#  11  OrderCode            9999 non-null   int64
# dtypes: float64(1), int64(5), object(6)
# memory usage: 937.5+ KB

# %% [markdown]
# #### Method 1

# %%
df.rename(columns={"Status": "Order_Status",
                   "Quantity": "Order_Quantity"}).head()
# Out:
#                OrderID  Order_Quantity  UnitPrice(USD)   Order_Status  \
# 0  2951110000999929511              92             238  Not Delivered
# 1  2181910000999921819              61             136  Not Delivered
# 2  3239110000999932391              67             235  Not Delivered
# 3  1112610000999911126              33             133    Not Shipped
# 4  1548310000999915483              13             189  Not Delivered
#
#     OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 0  2021-08-08       Healthcare         Pablo                  21
# 1  2021-10-03           Office         Pablo                  34
# 2  2021-09-27           Office       Kristen                  25
# 3  2021-07-30          Fashion         Abdul                  34
# 4  2021-08-15          Fashion        Stella                  24
#
#    Delivery_Time(Days) Shipping_Address Product_Code  OrderCode
# 0                 25.0        Singapore       HC-188     444116
# ...

# %%
# %%timeit
df.rename(columns={"Status": "Order_Status",
                   "Quantity": "Order_Quantity"}, inplace=True)
# Out:
# 177 µs ± 2.03 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %% [markdown]
# #### Method 2

# %%
df.rename(columns=str.upper).head()
# Out:
#                ORDERID  QUANTITY  UNITPRICE(USD)         STATUS   ORDERDATE  \
# 0  2951110000999929511        92             238  Not Delivered  2021-08-08
# 1  2181910000999921819        61             136  Not Delivered  2021-10-03
# 2  3239110000999932391        67             235  Not Delivered  2021-09-27
# 3  1112610000999911126        33             133    Not Shipped  2021-07-30
# 4  1548310000999915483        13             189  Not Delivered  2021-08-15
#
#   PRODUCT_CATEGORY SALES_MANAGER  SHIPPING_COST(USD)  DELIVERY_TIME(DAYS)  \
# 0       Healthcare         Pablo                  21                 25.0
# 1           Office         Pablo                  34                 14.0
# 2           Office       Kristen                  25                 11.0
# 3          Fashion         Abdul                  34                 24.0
# 4          Fashion        Stella                  24                 19.0
#
#   SHIPPING_ADDRESS PRODUCT_CODE  ORDERCODE
# ...

# %%
# %%timeit
df.rename(columns=str.upper, inplace=True)
# Out:
# 59.9 µs ± 394 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
df.rename(columns=str.capitalize).head()
# Out:
#                Orderid  Quantity  Unitprice(usd)         Status   Orderdate  \
# 0  2951110000999929511        92             238  Not Delivered  2021-08-08
# 1  2181910000999921819        61             136  Not Delivered  2021-10-03
# 2  3239110000999932391        67             235  Not Delivered  2021-09-27
# 3  1112610000999911126        33             133    Not Shipped  2021-07-30
# 4  1548310000999915483        13             189  Not Delivered  2021-08-15
#
#   Product_category Sales_manager  Shipping_cost(usd)  Delivery_time(days)  \
# 0       Healthcare         Pablo                  21                 25.0
# 1           Office         Pablo                  34                 14.0
# 2           Office       Kristen                  25                 11.0
# 3          Fashion         Abdul                  34                 24.0
# 4          Fashion        Stella                  24                 19.0
#
#   Shipping_address Product_code  Ordercode
# ...

# %%
def function_1(x):
    x = x.split('_')[0]
    return x

# %%
df.rename(columns=function_1).head()
# Out:
#                OrderID  Quantity  UnitPrice(USD)         Status   OrderDate  \
# 0  2951110000999929511        92             238  Not Delivered  2021-08-08
# 1  2181910000999921819        61             136  Not Delivered  2021-10-03
# 2  3239110000999932391        67             235  Not Delivered  2021-09-27
# 3  1112610000999911126        33             133    Not Shipped  2021-07-30
# 4  1548310000999915483        13             189  Not Delivered  2021-08-15
#
#       Product    Sales Shipping  Delivery   Shipping Product  OrderCode
# 0  Healthcare    Pablo       21      25.0  Singapore  HC-188     444116
# 1      Office    Pablo       34      14.0         UK   O-555     444772
# 2      Office  Kristen       25      11.0      Kenya   O-188     444666
# 3     Fashion    Abdul       34      24.0        USA   F-555     444007
# 4     Fashion   Stella       24      19.0      Kenya   F-555     444223

# %% [markdown]
# #### Method 3

# %%
df.columns
# Out:
# Index(['OrderID', 'Quantity', 'UnitPrice(USD)', 'Status', 'OrderDate',
#        'Product_Category', 'Sales_Manager', 'Shipping_Cost(USD)',
#        'Delivery_Time(Days)', 'Shipping_Address', 'Product_Code', 'OrderCode'],
#       dtype='object')

# %%
df.columns = ['1','2']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-1e7eb3503819> in <module>
# ----> 1 df.columns = ['1','2']
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5594         try:
#    5595             object.__getattribute__(self, name)
# -> 5596             return object.__setattr__(self, name, value)
#    5597         except AttributeError:
#    5598             pass
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     767     def _set_axis(self, axis: int, labels: Index) -> None:
#     768         labels = ensure_index(labels)
# --> 769         self._mgr.set_axis(axis, labels)
#     770         self._clear_item_cache()
#     771
#
# ...

# %%
df.columns = ['OrderID', 'Order_Quantity',
              'UnitPrice(USD)', 'Order_Status',
              'OrderDate', 'Product_Category',
              'Sales_Manager', 'Shipping_Cost(USD)',
              'Delivery_Time(Days)', 'Shipping_Address',
              'Product_Code', 'OrderCode']
df.head()
# Out:
#                OrderID  Order_Quantity  UnitPrice(USD)   Order_Status  \
# 0  2951110000999929511              92             238  Not Delivered
# 1  2181910000999921819              61             136  Not Delivered
# 2  3239110000999932391              67             235  Not Delivered
# 3  1112610000999911126              33             133    Not Shipped
# 4  1548310000999915483              13             189  Not Delivered
#
#     OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 0  2021-08-08       Healthcare         Pablo                  21
# 1  2021-10-03           Office         Pablo                  34
# 2  2021-09-27           Office       Kristen                  25
# 3  2021-07-30          Fashion         Abdul                  34
# 4  2021-08-15          Fashion        Stella                  24
#
#    Delivery_Time(Days) Shipping_Address Product_Code  OrderCode
# 0                 25.0        Singapore       HC-188     444116
# ...

# %%
# %%timeit
df.columns = ['OrderID', 'Order_Quantity',
              'UnitPrice(USD)', 'Order_Status',
              'OrderDate', 'Product_Category',
              'Sales_Manager', 'Shipping_Cost(USD)',
              'Delivery_Time(Days)', 'Shipping_Address',
              'Product_Code', 'OrderCode']
# Out:
# 65.8 µs ± 77.4 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %% [markdown]
# #### Method 4

# %%
df.set_axis(['A', 'B', 'C', 'D', 'E', 'F',
             'G', 'H', 'I', 'J', 'K', 'L'], axis=1).head()
# Out:
#                      A   B    C              D           E           F  \
# 0  2951110000999929511  92  238  Not Delivered  2021-08-08  Healthcare
# 1  2181910000999921819  61  136  Not Delivered  2021-10-03      Office
# 2  3239110000999932391  67  235  Not Delivered  2021-09-27      Office
# 3  1112610000999911126  33  133    Not Shipped  2021-07-30     Fashion
# 4  1548310000999915483  13  189  Not Delivered  2021-08-15     Fashion
#
#          G   H     I          J       K       L
# 0    Pablo  21  25.0  Singapore  HC-188  444116
# 1    Pablo  34  14.0         UK   O-555  444772
# 2  Kristen  25  11.0      Kenya   O-188  444666
# 3    Abdul  34  24.0        USA   F-555  444007
# 4   Stella  24  19.0      Kenya   F-555  444223

# %%
# %%timeit
df.set_axis(['A', 'B', 'C', 'D', 'E', 'F',
             'G', 'H', 'I', 'J', 'K', 'L'], axis=1, inplace=True)
# Out:
# 70.6 µs ± 281 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
