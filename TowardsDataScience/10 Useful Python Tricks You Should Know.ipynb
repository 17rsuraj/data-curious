# %%
import pandas as pd
from IPython.display import HTML, display, Image, Javascript
widget_style = {'description_width': 'initial'}
display(HTML(data="""<style>div#notebook-container    { width: 90%; }</style>"""))
# Out:
# <style>div#notebook-container    { width: 90%; }</style>

# %%
df = pd.read_csv("Airbnb_Open_Data.csv", low_memory=False)
df.head()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country  ... service fee minimum nights  \
# 0  40.64749 -73.97237  United States  ...       $193            10.0
# 1  40.75362 -73.98377  United States  ...        $28            30.0
# 2  40.80902 -73.94190  United States  ...       $124             3.0
# 3  40.68514 -73.95976  United States  ...        $74            30.0
# 4  40.79851 -73.94399  United States  ...        $41            10.0
#
#   number of reviews last review  reviews per month review rate number  \
# 0               9.0  10/19/2021               0.21                4.0
# 1              45.0   5/21/2022               0.38                4.0
# 2               0.0         NaN                NaN                5.0
# 3             270.0    7/5/2019               4.64                4.0
# 4               9.0  11/19/2018               0.10                3.0
#
#   calculated host listings count  availability 365  \
# 0                            6.0             286.0
# 1                            2.0             228.0
# 2                            1.0             352.0
# 3                            1.0             322.0
# 4                            1.0             289.0
#
#                                          house_rules license
# 0  Clean up and treat the home the way you'd like...     NaN
# 1  Pet friendly but please confirm with me if the...     NaN
# 2  I encourage you to use my kitchen, cooking and...     NaN
# 3                                                NaN     NaN
# 4  Please no smoking in the house, porch or on th...     NaN
#
# [5 rows x 26 columns]

# %% [markdown]
# #### Set Maximum and Minimum Rows to Display

# %%
pd.set_option("display.min_rows",7)

#check the max number of rows
pd.options.display.max_rows
# Out:
# 60

# %%
df
# Out:
#              id                                 NAME      host id  \
# 0       1001254   Clean & quiet apt home by the park  80014485718
# 1       1002102                Skylit Midtown Castle  52335172823
# 2       1002403  THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# ...         ...                                  ...          ...
# 102596  6093542       Comfy, bright room in Brooklyn  69050334417
# 102597  6094094     Big Studio-One Stop from Midtown  11160591270
# 102598  6094647                 585 sf Luxury Studio  68170633372
#
#        host_identity_verified    host name neighbourhood group  \
# 0                 unconfirmed     Madaline            Brooklyn
# 1                    verified        Jenna           Manhattan
# 2                         NaN        Elise           Manhattan
# ...                       ...          ...                 ...
# 102596            unconfirmed        Megan            Brooklyn
# 102597            unconfirmed  Christopher              Queens
# 102598            unconfirmed      Rebecca           Manhattan
#
#            neighbourhood       lat      long        country  ... service fee  \
# 0             Kensington  40.64749 -73.97237  United States  ...       $193
# 1                Midtown  40.75362 -73.98377  United States  ...        $28
# 2                 Harlem  40.80902 -73.94190  United States  ...       $124
# ...                  ...       ...       ...            ...  ...         ...
# 102596        Park Slope  40.67505 -73.98045  United States  ...       $198
# 102597  Long Island City  40.74989 -73.93777  United States  ...       $109
# 102598   Upper West Side  40.76807 -73.98342  United States  ...       $206
#
#        minimum nights number of reviews last review  reviews per month  \
# 0                10.0               9.0  10/19/2021               0.21
# 1                30.0              45.0   5/21/2022               0.38
# 2                 3.0               0.0         NaN                NaN
# ...               ...               ...         ...                ...
# 102596            3.0               0.0         NaN                NaN
# 102597            2.0               5.0  10/11/2015               0.10
# 102598            1.0               0.0         NaN                NaN
#
#        review rate number calculated host listings count  availability 365  \
# 0                     4.0                            6.0             286.0
# 1                     4.0                            2.0             228.0
# 2                     5.0                            1.0             352.0
# ...                   ...                            ...               ...
# 102596                5.0                            1.0             342.0
# 102597                3.0                            1.0             386.0
# 102598                3.0                            1.0              69.0
#
#                                               house_rules license
# 0       Clean up and treat the home the way you'd like...     NaN
# 1       Pet friendly but please confirm with me if the...     NaN
# 2       I encourage you to use my kitchen, cooking and...     NaN
# ...                                                   ...     ...
# 102596                                                NaN     NaN
# 102597                                                NaN     NaN
# 102598                                                NaN     NaN
#
# [102599 rows x 26 columns]

# %%
pd.set_option("display.max_columns",26)

#check the max number of rows
pd.options.display.max_columns
# Out:
# 26

# %%
df.head()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country country code instant_bookable  \
# 0  40.64749 -73.97237  United States           US            False
# 1  40.75362 -73.98377  United States           US            False
# 2  40.80902 -73.94190  United States           US             True
# 3  40.68514 -73.95976  United States           US             True
# 4  40.79851 -73.94399  United States           US            False
#
#   cancellation_policy        room type  Construction year  price service fee  \
# 0              strict     Private room             2020.0  $966        $193
# 1            moderate  Entire home/apt             2007.0  $142         $28
# 2            flexible     Private room             2005.0  $620        $124
# 3            moderate  Entire home/apt             2005.0  $368         $74
# 4            moderate  Entire home/apt             2009.0  $204         $41
#
#    minimum nights  number of reviews last review  reviews per month  \
# 0            10.0                9.0  10/19/2021               0.21
# 1            30.0               45.0   5/21/2022               0.38
# 2             3.0                0.0         NaN                NaN
# 3            30.0              270.0    7/5/2019               4.64
# 4            10.0                9.0  11/19/2018               0.10
#
#    review rate number  calculated host listings count  availability 365  \
# 0                 4.0                             6.0             286.0
# 1                 4.0                             2.0             228.0
# 2                 5.0                             1.0             352.0
# 3                 4.0                             1.0             322.0
# 4                 3.0                             1.0             289.0
#
#                                          house_rules license
# 0  Clean up and treat the home the way you'd like...     NaN
# 1  Pet friendly but please confirm with me if the...     NaN
# 2  I encourage you to use my kitchen, cooking and...     NaN
# 3                                                NaN     NaN
# 4  Please no smoking in the house, porch or on th...     NaN

# %% [markdown]
# #### Subset dataframe with .query()

# %%
pd.reset_option('display.max_columns')

# %% [markdown]
# ### Subset a dataframe with the query() method

# %%
df_subset = df[(df['neighbourhood'] == 'Kensington') & (df['cancellation_policy']=='strict')]
df_subset.head()
# Out:
#            id                                        NAME      host id  \
# 0     1001254          Clean & quiet apt home by the park  80014485718
# 787   1435996         Kensington/Ditmas Park pied-a-terre  69568692921
# 1213  1671276                         Lovely Brooklyn Apt   2445296350
# 1815  2003761  Vintage Chic Haven in Kensington, Brooklyn  16961253966
# 1927  2065618             Gorgeous 1BR near Prospect Park  79955192546
#
#      host_identity_verified host name neighbourhood group neighbourhood  \
# 0               unconfirmed  Madaline            Brooklyn    Kensington
# 787             unconfirmed  Sullivan            Brooklyn    Kensington
# 1213               verified   Bethany            Brooklyn    Kensington
# 1815            unconfirmed     Jesse            Brooklyn    Kensington
# 1927               verified     Rohit            Brooklyn    Kensington
#
#            lat      long        country country code instant_bookable  \
# 0     40.64749 -73.97237  United States           US            False
# 787   40.64330 -73.97386  United States           US            False
# 1213  40.64625 -73.97932  United States           US            False
# 1815  40.63547 -73.97417  United States           US             True
# 1927  40.64651 -73.97662  United States           US            False
#
#      cancellation_policy        room type  Construction year  price  \
# 0                 strict     Private room             2020.0  $966
# 787               strict  Entire home/apt             2017.0  $261
# 1213              strict  Entire home/apt             2021.0  $351
# 1815              strict     Private room             2008.0  $793
# 1927              strict  Entire home/apt             2014.0  $284
#
#      service fee  minimum nights  number of reviews last review  \
# 0          $193             10.0                9.0  10/19/2021
# 787         $52             30.0                3.0   7/30/2017
# 1213        $70             10.0               33.0   5/22/2019
# 1815       $159              1.0               61.0   6/23/2019
# 1927        $57              4.0               20.0   9/10/2017
#
#       reviews per month  review rate number  calculated host listings count  \
# 0                  0.21                 4.0                             6.0
# 787                0.05                 4.0                             1.0
# 1213               0.39                 4.0                             1.0
# 1815               0.95                 5.0                             1.0
# 1927               0.26                 1.0                             1.0
#
#       availability 365                                        house_rules  \
# 0                286.0  Clean up and treat the home the way you'd like...
# 787              108.0                     Absolutely no smoking or pets.
# 1213              65.0  Please respect the residents by keeping noise ...
# 1815              66.0                                                NaN
# 1927             315.0  Check-in after noon before 8pm. Check-out 11am...
#
#      license
# 0        NaN
# 787      NaN
# 1213     NaN
# 1815     NaN
# 1927     NaN

# %%
df.query("neighbourhood == 'Kensington'")
# Out:
#               id                                          NAME      host id  \
# 0        1001254            Clean & quiet apt home by the park  80014485718
# 259      1144382                Large and Cozy Private Bedroom  87014850347
# 398      1221151            SUPER BIG AND COZY PRIVATE BEDROOM  50336791874
# ...          ...                                           ...          ...
# 101768  57207802                       Huge room, Social Home!  82099382171
# 102149  35557090                           Modern Private ROOM   3638560773
# 102471  20409710  Sunny Apt in Brooklyn Close to Prospect Park  50600643853
#
#        host_identity_verified   host name neighbourhood group neighbourhood  \
# 0                 unconfirmed    Madaline            Brooklyn    Kensington
# 259               unconfirmed  Richardson            Brooklyn    Kensington
# 398                  verified      Tucker            Brooklyn    Kensington
# ...                       ...         ...                 ...           ...
# 101768            unconfirmed       Kelly            Brooklyn    Kensington
# 102149            unconfirmed    Kristina            Brooklyn    Kensington
# 102471            unconfirmed      Sophia            Brooklyn    Kensington
#
#              lat      long        country  ... service fee minimum nights  \
# 0       40.64749 -73.97237  United States  ...       $193            10.0
# 259     40.64106 -73.97426  United States  ...       $157             1.0
# 398     40.64302 -73.97255  United States  ...       $156            -1.0
# ...          ...       ...            ...  ...         ...            ...
# 101768  40.64465 -73.97871  United States  ...       $222             3.0
# 102149  40.63348 -73.97461  United States  ...        $52            30.0
# 102471  40.63472 -73.97268  United States  ...       $161             3.0
#
#        number of reviews last review  reviews per month review rate number  \
# 0                    9.0  10/19/2021               0.21                4.0
# 259                 45.0   5/16/2019               0.46                4.0
# 398                 82.0   5/19/2019               0.94                2.0
# ...                  ...         ...                ...                ...
# 101768               5.0   4/12/2017               0.18                4.0
# 102149               3.0   11/8/2021               0.45                2.0
# 102471               2.0    1/1/2019               0.19                3.0
#
#        calculated host listings count  availability 365  \
# 0                                 6.0             286.0
# 259                               2.0               NaN
# 398                               2.0             131.0
# ...                               ...               ...
# 101768                            1.0               0.0
# 102149                           11.0             365.0
# 102471                            1.0             281.0
#
#                                               house_rules license
# 0       Clean up and treat the home the way you'd like...     NaN
# 259     House quiet hours are from 10 pm to 8 am.  We ...     NaN
# 398     no inside smoking, quiet(ish) after 11, help y...     NaN
# ...                                                   ...     ...
# 101768                                                NaN     NaN
# 102149                                                NaN     NaN
# 102471  All guests are expected to be respectful and m...     NaN
#
# [369 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102599 non-null  int64
#  1   NAME                            102349 non-null  object
#  2   host id                         102599 non-null  int64
#  3   host_identity_verified          102310 non-null  object
#  4   host name                       102193 non-null  object
#  5   neighbourhood group             102570 non-null  object
#  6   neighbourhood                   102583 non-null  object
#  7   lat                             102591 non-null  float64
#  8   long                            102591 non-null  float64
#  9   country                         102067 non-null  object
#  10  country code                    102468 non-null  object
#  11  instant_bookable                102494 non-null  object
#  12  cancellation_policy             102523 non-null  object
#  13  room type                       102599 non-null  object
#  14  Construction year               102385 non-null  float64
#  15  price                           102352 non-null  object
#  16  service fee                     102326 non-null  object
#  17  minimum nights                  102190 non-null  float64
#  18  number of reviews               102416 non-null  float64
#  19  last review                     86706 non-null   object
#  20  reviews per month               86720 non-null   float64
#  21  review rate number              102273 non-null  float64
#  22  calculated host listings count  102280 non-null  float64
#  23  availability 365                102151 non-null  float64
#  24  house_rules                     50468 non-null   object
#  25  license                         2 non-null       object
# dtypes: float64(9), int64(2), object(15)
# memory usage: 20.4+ MB

# %% [markdown]
# ### Change the number of decimal places in a column with the round() method

# %%
df.round(2)
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# 1       52335172823               verified        Jenna           Manhattan
# 2       78829239556                    NaN        Elise           Manhattan
# 3       85098326012            unconfirmed        Garry            Brooklyn
# 4       92037596077               verified       Lyndon           Manhattan
# ...             ...                    ...          ...                 ...
# 102594  12312296767               verified         Krik            Brooklyn
# 102595  77864383453            unconfirmed        Mifan           Manhattan
# 102596  69050334417            unconfirmed        Megan            Brooklyn
# 102597  11160591270            unconfirmed  Christopher              Queens
# 102598  68170633372            unconfirmed      Rebecca           Manhattan
#
#               neighbourhood    lat   long        country  ... service fee  \
# 0                Kensington  40.65 -73.97  United States  ...       $193
# 1                   Midtown  40.75 -73.98  United States  ...        $28
# 2                    Harlem  40.81 -73.94  United States  ...       $124
# 3              Clinton Hill  40.69 -73.96  United States  ...        $74
# 4               East Harlem  40.80 -73.94  United States  ...        $41
# ...                     ...    ...    ...            ...  ...         ...
# 102594         Williamsburg  40.71 -73.95  United States  ...       $169
# 102595  Morningside Heights  40.80 -73.97  United States  ...       $167
# 102596           Park Slope  40.68 -73.98  United States  ...       $198
# 102597     Long Island City  40.75 -73.94  United States  ...       $109
# 102598      Upper West Side  40.77 -73.98  United States  ...       $206
#
#        minimum nights number of reviews last review  reviews per month  \
# 0                10.0               9.0  10/19/2021               0.21
# 1                30.0              45.0   5/21/2022               0.38
# 2                 3.0               0.0         NaN                NaN
# 3                30.0             270.0    7/5/2019               4.64
# 4                10.0               9.0  11/19/2018               0.10
# ...               ...               ...         ...                ...
# 102594            1.0               0.0         NaN                NaN
# 102595            1.0               1.0    7/6/2015               0.02
# 102596            3.0               0.0         NaN                NaN
# 102597            2.0               5.0  10/11/2015               0.10
# 102598            1.0               0.0         NaN                NaN
#
#        review rate number calculated host listings count  availability 365  \
# 0                     4.0                            6.0             286.0
# 1                     4.0                            2.0             228.0
# 2                     5.0                            1.0             352.0
# 3                     4.0                            1.0             322.0
# 4                     3.0                            1.0             289.0
# ...                   ...                            ...               ...
# 102594                3.0                            1.0             227.0
# 102595                2.0                            2.0             395.0
# 102596                5.0                            1.0             342.0
# 102597                3.0                            1.0             386.0
# 102598                3.0                            1.0              69.0
#
#                                               house_rules license
# 0       Clean up and treat the home the way you'd like...     NaN
# 1       Pet friendly but please confirm with me if the...     NaN
# 2       I encourage you to use my kitchen, cooking and...     NaN
# 3                                                     NaN     NaN
# 4       Please no smoking in the house, porch or on th...     NaN
# ...                                                   ...     ...
# 102594  No Smoking No Parties or Events of any kind Pl...     NaN
# 102595  House rules: Guests agree to the following ter...     NaN
# 102596                                                NaN     NaN
# 102597                                                NaN     NaN
# 102598                                                NaN     NaN
#
# [102599 rows x 26 columns]

# %%
df['lat'].round(2)
# Out:
# 0         40.65
# 1         40.75
# 2         40.81
#           ...
# 102596    40.68
# 102597    40.75
# 102598    40.77
# Name: lat, Length: 102599, dtype: float64

# %%
df['lat'] = df['lat'].round(2)
df.head()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood    lat  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington  40.65
# 1               verified     Jenna           Manhattan       Midtown  40.75
# 2                    NaN     Elise           Manhattan        Harlem  40.81
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill  40.69
# 4               verified    Lyndon           Manhattan   East Harlem  40.80
#
#        long        country  ... service fee minimum nights number of reviews  \
# 0 -73.97237  United States  ...       $193            10.0               9.0
# 1 -73.98377  United States  ...        $28            30.0              45.0
# 2 -73.94190  United States  ...       $124             3.0               0.0
# 3 -73.95976  United States  ...        $74            30.0             270.0
# 4 -73.94399  United States  ...        $41            10.0               9.0
#
#   last review  reviews per month review rate number  \
# 0  10/19/2021               0.21                4.0
# 1   5/21/2022               0.38                4.0
# 2         NaN                NaN                5.0
# 3    7/5/2019               4.64                4.0
# 4  11/19/2018               0.10                3.0
#
#   calculated host listings count  availability 365  \
# 0                            6.0             286.0
# 1                            2.0             228.0
# 2                            1.0             352.0
# 3                            1.0             322.0
# 4                            1.0             289.0
#
#                                          house_rules license
# 0  Clean up and treat the home the way you'd like...     NaN
# 1  Pet friendly but please confirm with me if the...     NaN
# 2  I encourage you to use my kitchen, cooking and...     NaN
# 3                                                NaN     NaN
# 4  Please no smoking in the house, porch or on th...     NaN
#
# [5 rows x 26 columns]

# %% [markdown]
# ### Unpack the list values with the explode() method

# %%
df1 = pd.DataFrame({"Country":["India","Germany"],
                   "State":[["Maharashtra", "Telangana", "Gujarat"],
                            ["Bavaria", "Hessen"]]})

df2 = df1.explode("State")

# Get both DataFrames as output
df1
df2
# Out:
#    Country        State
# 0    India  Maharashtra
# 0    India    Telangana
# 0    India      Gujarat
# 1  Germany      Bavaria
# 1  Germany       Hessen

# %% [markdown]
# ### Return multiple DataFrames with display()

# %%
df1 = pd.DataFrame({"Country":["India","Germany"],
                   "State":[["Maharashtra", "Telangana", "Gujarat"],
                            ["Bavaria", "Hessen"]]})

df2 = df1.explode("State")

# Get both DataFrames as output
display(df1)
display(df2)
# Out:
#    Country                              State
# 0    India  [Maharashtra, Telangana, Gujarat]
# 1  Germany                  [Bavaria, Hessen]
#    Country        State
# 0    India  Maharashtra
# 0    India    Telangana
# 0    India      Gujarat
# 1  Germany      Bavaria
# 1  Germany       Hessen

# %%
df.head()
df1.head()
# Out:
#    Country                              State
# 0    India  [Maharashtra, Telangana, Gujarat]
# 1  Germany                  [Bavaria, Hessen]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102599 non-null  int64
#  1   NAME                            102349 non-null  object
#  2   host id                         102599 non-null  int64
#  3   host_identity_verified          102310 non-null  object
#  4   host name                       102193 non-null  object
#  5   neighbourhood group             102570 non-null  object
#  6   neighbourhood                   102583 non-null  object
#  7   lat                             102591 non-null  float64
#  8   long                            102591 non-null  float64
#  9   country                         102067 non-null  object
#  10  country code                    102468 non-null  object
#  11  instant_bookable                102494 non-null  object
#  12  cancellation_policy             102523 non-null  object
#  13  room type                       102599 non-null  object
#  14  Construction year               102385 non-null  float64
#  15  price                           102352 non-null  object
#  16  service fee                     102326 non-null  object
#  17  minimum nights                  102190 non-null  float64
#  18  number of reviews               102416 non-null  float64
#  19  last review                     86706 non-null   object
#  20  reviews per month               86720 non-null   float64
#  21  review rate number              102273 non-null  float64
#  22  calculated host listings count  102280 non-null  float64
#  23  availability 365                102151 non-null  float64
#  24  house_rules                     50468 non-null   object
#  25  license                         2 non-null       object
# dtypes: float64(9), int64(2), object(15)
# memory usage: 20.4+ MB

# %% [markdown]
# ### Create quick plots with the plot() method

# %%
df_room = pd.DataFrame(df.groupby('room type')['number of reviews'].mean())
df_room.reset_index(drop=False, inplace=True)
display(df_room)
df_room.plot(x='room type', y='number of reviews', kind='bar')
# Out:
#          room type  number of reviews
# 0  Entire home/apt          27.375881
# 1       Hotel room          83.439655
# 2     Private room          27.808926
# 3      Shared room          20.380952
# <AxesSubplot:xlabel='room type'>

# %%
df_room = pd.DataFrame(df.groupby('room type')['number of reviews'].mean())
df_room.reset_index(drop=False, inplace=True)
display(df_room)
df_room.plot(x='room type', y='number of reviews', kind='line')
# Out:
#          room type  number of reviews
# 0  Entire home/apt          27.375881
# 1       Hotel room          83.439655
# 2     Private room          27.808926
# 3      Shared room          20.380952
# <AxesSubplot:xlabel='room type'>

# %%
df_room = pd.DataFrame(df.groupby('room type')['number of reviews'].mean())
df_room.reset_index(drop=False, inplace=True)
display(df_room)
df_room.plot(x='room type', y='number of reviews', kind='barh')
# Out:
#          room type  number of reviews
# 0  Entire home/apt          27.375881
# 1       Hotel room          83.439655
# 2     Private room          27.808926
# 3      Shared room          20.380952
# <AxesSubplot:ylabel='room type'>

# %%
df.plot(x='room type', y='number of reviews', kind='box')
# Out:
# <AxesSubplot:>

# %%
df_room = pd.DataFrame(df.groupby('room type')['number of reviews'].mean())
df_room.reset_index(drop=False, inplace=True)
display(df_room)
df_room.plot(x='room type', y='number of reviews', kind='scatter')
# Out:
#          room type  number of reviews
# 0  Entire home/apt          27.375881
# 1       Hotel room          83.439655
# 2     Private room          27.808926
# 3      Shared room          20.380952
# <AxesSubplot:xlabel='room type', ylabel='number of reviews'>

# %%
df_room = pd.DataFrame(df.groupby('room type')['number of reviews'].mean())
df_room.reset_index(drop=False, inplace=True)
display(df_room)
df_room.plot(x='room type', y='number of reviews', kind='density')
# Out:
#          room type  number of reviews
# 0  Entire home/apt          27.375881
# 1       Hotel room          83.439655
# 2     Private room          27.808926
# 3      Shared room          20.380952
# <AxesSubplot:ylabel='Density'>

# %%
df_room = pd.DataFrame(df.groupby('room type')['number of reviews'].mean())
df_room.reset_index(drop=False, inplace=True)
display(df_room)
df_room.plot(x='room type', y='number of reviews', kind='area')
# Out:
#          room type  number of reviews
# 0  Entire home/apt          27.375881
# 1       Hotel room          83.439655
# 2     Private room          27.808926
# 3      Shared room          20.380952
# <AxesSubplot:xlabel='room type'>

# %%
df_room = pd.DataFrame(df.groupby('room type')['number of reviews'].mean())
df_room.reset_index(drop=False, inplace=True)
display(df_room)
df_room.plot(x='room type', y='number of reviews', kind='pie')
# Out:
#          room type  number of reviews
# 0  Entire home/apt          27.375881
# 1       Hotel room          83.439655
# 2     Private room          27.808926
# 3      Shared room          20.380952
# <AxesSubplot:ylabel='number of reviews'>

# %%
df_room = pd.DataFrame(df.groupby('room type')['number of reviews'].mean())
df_room.reset_index(drop=False, inplace=True)
display(df_room)
df_room.plot(x='room type', y='number of reviews', kind='kde')
# Out:
#          room type  number of reviews
# 0  Entire home/apt          27.375881
# 1       Hotel room          83.439655
# 2     Private room          27.808926
# 3      Shared room          20.380952
# <AxesSubplot:ylabel='Density'>

# %%
df.plot(y='number of reviews', kind='hist')
# Out:
#          room type  number of reviews
# 0  Entire home/apt          27.375881
# 1       Hotel room          83.439655
# 2     Private room          27.808926
# 3      Shared room          20.380952
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ### Count unique values with nunique()

# %%
df['room type'].nunique()
# Out:
# 4

# %%
df['room type'].unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room', 'Hotel room'],
#       dtype=object)

# %%
df.value_counts('room type')
# Out:
# room type
# Entire home/apt    53701
# Private room       46556
# Shared room         2226
# Hotel room           116
# dtype: int64

# %% [markdown]
# ### Return a cumulative summary with cumsum()

# %%
daterange = pd.date_range('2022-11-24', periods=5, freq='2D')
df1 = pd.DataFrame({ 'Date': daterange,
                    'Products_sold' : [10, 15, 20, 25, 4]})
df1
# Out:
#         Date  Products_sold
# 0 2022-11-24             10
# 1 2022-11-26             15
# 2 2022-11-28             20
# 3 2022-11-30             25
# 4 2022-12-02              4

# %%
df1["Products_sold"].cumsum()
# Out:
# 0    10
# 1    25
# 2    45
# 3    70
# 4    74
# Name: Products_sold, dtype: int64

# %%
df1["Total_products_sold"] = df1["Products_sold"].cumsum()
df1
# Out:
#         Date  Products_sold  Total_products_sold
# 0 2022-11-24             10                   10
# 1 2022-11-26             15                   25
# 2 2022-11-28             20                   45
# 3 2022-11-30             25                   70
# 4 2022-12-02              4                   74

# %%
df_room = df.groupby('room type')
df_room

# %%
df_room.agg({'number of reviews': sum,
             'minimum nights': sum})
# Out:
#                  number of reviews  minimum nights
# room type
# Entire home/apt          1468059.0        524475.0
# Hotel room                  9679.0           471.0
# Private room             1291669.0        291783.0
# Shared room                45368.0         14673.0

# %% [markdown]
# ### Randomly sample rows with sample()

# %%
df.sample(4)
# Out:
#              id                                               NAME  \
# 13003   8182893                   Bright, cozy, room in Greenpoint
# 34467  20037460   Private Bushwick Room -- Close to J, M, L Trains
# 75848  42892186                                       Harlem River
# 54203  30937653  Fully Furnished 2BR Apartment in Midtown Manha...
#
#            host id host_identity_verified host name neighbourhood group  \
# 13003  34486779669               verified   Johanna            Brooklyn
# 34467  67405385322               verified    Keilyn            Brooklyn
# 75848  36132158850            unconfirmed   Ermanno           Manhattan
# 54203  47292306758            unconfirmed       Avi           Manhattan
#
#         neighbourhood       lat      long        country  ... service fee  \
# 13003      Greenpoint  40.72522 -73.95124  United States  ...        $37
# 34467        Bushwick  40.70055 -73.93024  United States  ...       $225
# 75848     East Harlem  40.81344 -73.93454  United States  ...       $146
# 54203  Hell's Kitchen  40.76577 -73.98375  United States  ...       $115
#
#       minimum nights number of reviews last review  reviews per month  \
# 13003            1.0               0.0         NaN                NaN
# 34467            2.0              32.0   6/25/2019               2.97
# 75848            2.0               7.0    9/4/2017               0.21
# 54203           30.0               1.0   2/14/2022               1.00
#
#       review rate number calculated host listings count  availability 365  \
# 13003                2.0                            1.0               2.0
# 34467                2.0                            1.0             158.0
# 75848                3.0                            1.0              32.0
# 54203                4.0                           63.0             342.0
#
#                                              house_rules license
# 13003  No smoking No pets We don't charge a cleaning ...     NaN
# 34467  No Smoking anywhere on the property!  DO NOT a...     NaN
# 75848                               Smoke deck out back.     NaN
# 54203                                                NaN     NaN
#
# [4 rows x 26 columns]

# %%
df.sample(frac = 0.00005)
# Out:
#               id                                               NAME  \
# 100879  56716808  Sunny Private Room close to Central Park - Harlem
# 18       1011277                                    Chelsea Perfect
# 26873   15843294        Modern Home, Amazing Location Sunshine room
# 6196     4423387                 Spacious Manhattan One Bedroom Apt
# 27422   16146507                       Cozy Gramercy Park 1 bedroom
#
#             host id host_identity_verified host name neighbourhood group  \
# 100879  64807432817               verified   Sherian           Manhattan
# 18      73862528370               verified   Alberta            manhatan
# 26873   44930646371            unconfirmed  Jermaine            Brooklyn
# 6196    43624753189            unconfirmed      Luke           Manhattan
# 27422   71848902531               verified       Kah           Manhattan
#
#              neighbourhood       lat      long        country  ...  \
# 100879         East Harlem  40.79602 -73.94884  United States  ...
# 18                 Chelsea  40.74192 -73.99501  United States  ...
# 26873             Canarsie  40.64162 -73.90915  United States  ...
# 6196    Washington Heights  40.85520 -73.93354  United States  ...
# 27422             Kips Bay  40.73801 -73.98099  United States  ...
#
#        service fee minimum nights number of reviews last review  \
# 100879       $175             1.0               6.0   7/20/2017
# 18             NaN            1.0             260.0    7/1/2019
# 26873         $80             3.0               1.0    1/2/2018
# 6196          $62             1.0             150.0   6/28/2019
# 27422        $141             3.0               2.0    1/3/2018
#
#         reviews per month review rate number calculated host listings count  \
# 100879               0.23                5.0                            1.0
# 18                   2.12                3.0                            1.0
# 26873                0.05                3.0                            4.0
# 6196                 2.68                2.0                            1.0
# 27422                0.10                2.0                            1.0
#
#         availability 365                                        house_rules  \
# 100879               0.0                                                NaN
# 18                 325.0                                                NaN
# 26873              364.0  Please remember that this is a residential bui...
# 6196               358.0                                                NaN
# 27422                0.0                                                NaN
#
#        license
# 100879     NaN
# 18         NaN
# 26873      NaN
# 6196       NaN
# 27422      NaN
#
# [5 rows x 26 columns]

# %%
df.sample(3, random_state = 4)
# Out:
#              id                                               NAME  \
# 51177  29266393  Blue Moon Hotel | 720 sq ft King Room with 300...
# 12240   7761488                   Private room in Wash Heights NYC
# 75264  42569643                        Stylish Manhattan Bedroom!!
#
#            host id host_identity_verified  host name neighbourhood group  \
# 51177  86400944152               verified  Blue Moon           Manhattan
# 12240   3878787740            unconfirmed    Raphael           Manhattan
# 75264  42832662660               verified        Jay           Manhattan
#
#             neighbourhood       lat      long        country  ... service fee  \
# 51177     Lower East Side  40.71964 -73.99067  United States  ...       $223
# 12240  Washington Heights  40.85068 -73.93046  United States  ...       $231
# 75264              Harlem  40.81590 -73.93960  United States  ...       $189
#
#       minimum nights number of reviews last review  reviews per month  \
# 51177            1.0              16.0   2/27/2022               2.82
# 12240            4.0               1.0    1/2/2016               0.02
# 75264            1.0               4.0    7/5/2019               1.14
#
#       review rate number calculated host listings count  availability 365  \
# 51177                4.0                           27.0             307.0
# 12240                2.0                            1.0             353.0
# 75264                4.0                            9.0             260.0
#
#                             house_rules license
# 51177                               NaN     NaN
# 12240  Clean, respectful, no parties :)     NaN
# 75264                               NaN     NaN
#
# [3 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102599 non-null  int64
#  1   NAME                            102349 non-null  object
#  2   host id                         102599 non-null  int64
#  3   host_identity_verified          102310 non-null  object
#  4   host name                       102193 non-null  object
#  5   neighbourhood group             102570 non-null  object
#  6   neighbourhood                   102583 non-null  object
#  7   lat                             102591 non-null  float64
#  8   long                            102591 non-null  float64
#  9   country                         102067 non-null  object
#  10  country code                    102468 non-null  object
#  11  instant_bookable                102494 non-null  object
#  12  cancellation_policy             102523 non-null  object
#  13  room type                       102599 non-null  object
#  14  Construction year               102385 non-null  float64
#  15  price                           102352 non-null  object
#  16  service fee                     102326 non-null  object
#  17  minimum nights                  102190 non-null  float64
#  18  number of reviews               102416 non-null  float64
#  19  last review                     86706 non-null   object
#  20  reviews per month               86720 non-null   float64
#  21  review rate number              102273 non-null  float64
#  22  calculated host listings count  102280 non-null  float64
#  23  availability 365                102151 non-null  float64
#  24  house_rules                     50468 non-null   object
#  25  license                         2 non-null       object
# dtypes: float64(9), int64(2), object(15)
# memory usage: 20.4+ MB
